# %% [markdown]
# <a href="https://colab.research.google.com/github/imrhuskhn12-alt/ITAI_ML_FirstRepo_EvanGibson/blob/main/hello_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Machine Learning!")
# Out:
# Hello, Machine Learning!

# %%
print("Hello from Imran Khan")
# Out:
# Hello from Imran Khan
